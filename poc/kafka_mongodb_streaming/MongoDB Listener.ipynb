# %%
# !pip uninstall pymongo
# !pip install pymongo[srv]

# %%
import sys
sys.path.append("/content/drive/MyDrive")
import mykeys

# %%
import os
import pymongo
from bson.json_util import dumps

mongo_uri = f"mongodb+srv://{mykeys.MONGODB_USER}:{mykeys.MONGODB_PASSWORD}@cluster0.z1rvm.mongodb.net/myFirstDatabase?retryWrites=true&w=majority"
client = pymongo.MongoClient(mongo_uri)

# %%
import pandas as pd
movies = pd.DataFrame(columns=['_id','movieId','title','genres'])

# %%
change_stream = client.movielens.movies.watch()
for change in change_stream:
  _temp = change['fullDocument']
  movies = movies.append(pd.DataFrame(_temp, columns=_temp.keys(), index=[0]), ignore_index=True)
  display(movies)
# Out:
#                         _id movieId                    title          genres
# 0  609d30d275bb9a6fb23372e9       3  Grumpier Old Men (1995)  Comedy|Romance
#                         _id  ...                genres
# 0  609d30d275bb9a6fb23372e9  ...        Comedy|Romance
# 1  609d317875bb9a6fb23372ea  ...  Comedy|Drama|Romance
#
# [2 rows x 4 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-dca8d5777c8b> in <module>()
#       1 change_stream = client.movielens.movies.watch()
# ----> 2 for change in change_stream:
#       3   _temp = change['fullDocument']
#       4   movies = movies.append(pd.DataFrame(_temp, columns=_temp.keys(), index=[0]), ignore_index=True)
#       5   display(movies)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in next(self)
#     247         """
#     248         while self.alive:
# --> 249             doc = self.try_next()
#     250             if doc is not None:
#     251                 return doc
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in try_next(self)
#     301         # one resume attempt.
#     302         try:
# --> 303             change = self._cursor._try_next(True)
#     304         except (ConnectionFailure, CursorNotFound):
#     305             self._resume()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     268         """Advance the cursor blocking for at most one getMore command."""
#     269         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 270             self._refresh()
#     271         if len(self.__data):
#     272             coll = self.__collection
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _refresh(self)
#     204                                     self.__collection.database.client,
#     205                                     self.__max_await_time_ms,
# --> 206                                     False))
#     207         else:  # Cursor id is zero nothing else to return
#     208             self.__killed = True
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     138         try:
#     139             response = client._run_operation_with_response(
# --> 140                 operation, self._unpack_response, address=self.__address)
#     141         except OperationFailure:
#     142             kill()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _run_operation_with_response(self, operation, unpack_res, exhaust, address)
#    1370             address=address,
#    1371             retryable=isinstance(operation, message._Query),
# -> 1372             exhaust=exhaust)
#    1373
#    1374     def _retry_with_session(self, retryable, func, session, bulk):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
#    1469                         # not support retryable reads, raise the last error.
#    1470                         raise last_error
# -> 1471                     return func(session, server, sock_info, slave_ok)
#    1472             except ServerSelectionTimeoutError:
#    1473                 if retrying:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, slave_ok)
#    1364                 self._event_listeners,
#    1365                 exhaust,
# -> 1366                 unpack_res)
#    1367
#    1368         return self._retryable_read(
#
# /usr/local/lib/python3.7/dist-packages/pymongo/server.py in run_operation_with_response(self, sock_info, operation, set_slave_okay, listeners, exhaust, unpack_res)
#     115             if send_message:
#     116                 sock_info.send_message(data, max_doc_size)
# --> 117                 reply = sock_info.receive_message(request_id)
#     118             else:
#     119                 reply = sock_info.receive_message(None)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     724             return receive_message(self, request_id, self.max_message_size)
#     725         except BaseException as error:
# --> 726             self._raise_connection_failure(error)
#     727
#     728     def _raise_if_not_writable(self, unacknowledged):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     722         """
#     723         try:
# --> 724             return receive_message(self, request_id, self.max_message_size)
#     725         except BaseException as error:
#     726             self._raise_connection_failure(error)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     193     # Ignore the response's request id.
#     194     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 195         _receive_data_on_socket(sock_info, 16, deadline))
#     196     # No request_id for exhaust cursor "getMore".
#     197     if request_id is not None:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     284             try:
#     285                 wait_for_read(sock_info, deadline)
# --> 286                 chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     287             except (IOError, OSError) as exc:
#     288                 if _errno_from_exception(exc) == errno.EINTR:
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
